# %% [markdown]
# # CAPSTONE PROJECT

# %% [markdown]
# **<span style='background: pink'><span style='color:purple'>  Week 1 Assignment  </span></span>**

# %% [markdown]
# __This notebook will be mainly used for the capstone project__

# %% [markdown]
# ***We will perform the below three steps now -***

# %% [markdown]
# 1. Import the pandas library as pd.
# 2. Import the Numpy library as np.
# 3. Print the following the statement: Hello Capstone Project Course!

# %%
# Import the pandas library as pd
import pandas as pd

# %%
# Import the Numpy library as pd
import numpy as np

# %%
#Print the following the statement: Hello Capstone Project Course!
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
